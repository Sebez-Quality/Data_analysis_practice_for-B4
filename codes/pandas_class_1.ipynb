# %%
# !pip install pandas   
import pandas as pd

# %%
print(pd.__version__)
# Out:
# 2.1.4

# %%
data = [10,20,30,40,50]
data_series = pd.Series(data)
print(data_series)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
type(data)
# Out:
# set

# %%
# data series with  given index
data = [100, 200,300,400]
index =['A','B','C','D']
df = pd.Series(data,  index=index)
print(df)
# Out:
# A    100
# B    200
# C    300
# D    400
# dtype: int64

# %%
# Series from dictionary
data = {
    1:1,2:4,3:9,4:16
}
df = pd.Series(data)

# %%
df
# Out:
# 1     1
# 2     4
# 3     9
# 4    16
# dtype: int64

# %% [markdown]
# # DataFrame

# %%
data = {
    'name':['Elias', 'Addis','Selam'],
    'age':[33,35,28],
    'salary':[30000,40000,5000]
    
}
df = pd.DataFrame(data)

# %%
df
# Out:
#     name  age  salary
# 0  Elias   33   30000
# 1  Addis   35   40000
# 2  Selam   28    5000

# %%
data = [
    ['name','age', 'gender'],
    ['Solomon',39,'M'],
    ['Kirubel', 53,'M'],
    ['Aster',33, 'F']
]

df = pd.DataFrame(data)
df
# Out:
#          0    1       2
# 0     name  age  gender
# 1  Solomon   39       M
# 2  Kirubel   53       M
# 3    Aster   33       F

# %% [markdown]
# # Import dataset

# %%
print(" Hello teams. \nAre you doing well?")
# Out:
#  Hello teams.
# Are you doing well?

# %%
file_path = r'C:\Users\1221\OneDrive\Desktop\craft\Data Analysis\class\files\employees.csv'
df = pd.read_csv(file_path)

# %%
df
# Out:
#    First Name  Gender            Department  Bonus % Senior   Salary  Age
# 0     Douglas    Male             Marketing    6.945    True   97308   33
# 1      Thomas    Male                   NaN    4.170    True   61933   28
# 2       Maria  Female               Finance   11.858   False  130590   45
# 3       Jerry    Male               Finance    9.340    True  138705   32
# 4       Larry    Male       Client Services    1.389    True  101004   21
# 5      Dennis    Male                 Legal   10.125   False  115163   27
# 6        Ruby  Female               Product   10.012    True   65476   37
# 7         NaN  Female               Finance   11.598     NaN   45906   44
# 8      Angela  Female           Engineering   18.523    True   95570   34
# 9     Frances  Female  Business Development    7.524    True  139852   35
# 10     Louise  Female                   NaN   15.132    True   63241   31
# 11      Julie  Female                 Legal   12.637    True  102508   21
# ...

# %%
df.head()
# Out:
#   First Name  Gender       Department  Bonus % Senior   Salary  Age
# 0    Douglas    Male        Marketing    6.945    True   97308   33
# 1     Thomas    Male              NaN    4.170    True   61933   28
# 2      Maria  Female          Finance   11.858   False  130590   45
# 3      Jerry    Male          Finance    9.340    True  138705   32
# 4      Larry    Male  Client Services    1.389    True  101004   21

# %%
df.head(10)
# Out:
#   First Name  Gender            Department  Bonus % Senior   Salary  Age
# 0    Douglas    Male             Marketing    6.945    True   97308   33
# 1     Thomas    Male                   NaN    4.170    True   61933   28
# 2      Maria  Female               Finance   11.858   False  130590   45
# 3      Jerry    Male               Finance    9.340    True  138705   32
# 4      Larry    Male       Client Services    1.389    True  101004   21
# 5     Dennis    Male                 Legal   10.125   False  115163   27
# 6       Ruby  Female               Product   10.012    True   65476   37
# 7        NaN  Female               Finance   11.598     NaN   45906   44
# 8     Angela  Female           Engineering   18.523    True   95570   34
# 9    Frances  Female  Business Development    7.524    True  139852   35

# %%
df.head(21)
# Out:
#    First Name  Gender            Department  Bonus % Senior   Salary  Age
# 0     Douglas    Male             Marketing    6.945    True   97308   33
# 1      Thomas    Male                   NaN    4.170    True   61933   28
# 2       Maria  Female               Finance   11.858   False  130590   45
# 3       Jerry    Male               Finance    9.340    True  138705   32
# 4       Larry    Male       Client Services    1.389    True  101004   21
# 5      Dennis    Male                 Legal   10.125   False  115163   27
# 6        Ruby  Female               Product   10.012    True   65476   37
# 7         NaN  Female               Finance   11.598     NaN   45906   44
# 8      Angela  Female           Engineering   18.523    True   95570   34
# 9     Frances  Female  Business Development    7.524    True  139852   35
# 10     Louise  Female                   NaN   15.132    True   63241   31
# 11      Julie  Female                 Legal   12.637    True  102508   21
# ...

# %%
df.tail()
# Out:
#    First Name  Gender       Department  Bonus % Senior   Salary  Age
# 45     Brenda  Female  Client Services    4.337   False  141521   35
# 46       Judy  Female  Human Resources    2.304   False   65931   38
# 47       Todd    Male          Finance   10.985    True   69989   35
# 48       Lois  Female  Client Services    9.999    True  147183   38
# 49     Walter     NaN     Distribution   18.099   False   66757   25

# %%
df.tail(11)
# Out:
#    First Name  Gender            Department  Bonus % Senior   Salary  Age
# 39       Alan    Male       Client Services    7.797     NaN  122173   49
# 40       Ruby  Female  Business Development    1.139   False  105946   34
# 41      Kevin    Male  Business Development    9.635   False   46080   43
# 42     Arthur    Male       Human Resources    6.147    True  134610   42
# 43       Carl     NaN       Client Services   12.345   False  125104   28
# 44       Todd    Male           Engineering    1.612    True  107281   21
# 45     Brenda  Female       Client Services    4.337   False  141521   35
# 46       Judy  Female       Human Resources    2.304   False   65931   38
# 47       Todd    Male               Finance   10.985    True   69989   35
# 48       Lois  Female       Client Services    9.999    True  147183   38
# 49     Walter     NaN          Distribution   18.099   False   66757   25

# %%
file_path = r'C:\Users\1221\OneDrive\Desktop\craft\Data Analysis\class\files\car_details.csv'
car = pd.read_csv(file_path)
car
# Out:
#                               name  year  selling_price  km_driven    fuel  \
# 0           Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2         Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3        Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4           Maruti Swift VXI BSIII  2007         130000     120000  Petrol
# ...                            ...   ...            ...        ...     ...
# 8123             Hyundai i20 Magna  2013         320000     110000  Petrol
# 8124         Hyundai Verna CRDi SX  2007         135000     119000  Diesel
# 8125        Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8126               Tata Indigo CR4  2013         290000      25000  Diesel
# 8127               Tata Indigo CR4  2013         290000      25000  Diesel
#
# ...

# %%
car.tail(12)
# Out:
#                                    name  year  selling_price  km_driven  \
# 8116         Maruti Alto K10 VXI Airbag  2017         340000      45000
# 8117             Maruti Swift Dzire VDI  2015         625000      50000
# 8118                  Hyundai i20 Magna  2013         380000      25000
# 8119        Maruti Wagon R LXI Optional  2017         360000      80000
# 8120            Hyundai Santro Xing GLS  2008         120000     191000
# 8121  Maruti Wagon R VXI BS IV with ABS  2013         260000      50000
# 8122         Hyundai i20 Magna 1.4 CRDi  2014         475000      80000
# 8123                  Hyundai i20 Magna  2013         320000     110000
# 8124              Hyundai Verna CRDi SX  2007         135000     119000
# 8125             Maruti Swift Dzire ZDi  2009         382000     120000
# 8126                    Tata Indigo CR4  2013         290000      25000
# 8127                    Tata Indigo CR4  2013         290000      25000
#
# ...

# %%
import pandas as pd
dfn = pd.read_csv('bestsellers.csv')
dfn
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
x = dfn[dfn['Price']>10]
x.head(7)
# Out:
#                                                  Name  \
# 1                                   11/22/63: A Novel
# 2             12 Rules for Life: An Antidote to Chaos
# 4   5,000 Awesome Facts (About Everything!) (Natio...
# 5       A Dance with Dragons (A Song of Ice and Fire)
# 6   A Game of Thrones / A Clash of Kings / A Storm...
# 7                      A Gentleman in Moscow: A Novel
# 12                            A Stolen Life: A Memoir
#
#                       Author  User Rating  Reviews  Price  Year        Genre
# 1               Stephen King          4.6     2052     22  2011      Fiction
# 2         Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 4   National Geographic Kids          4.8     7665     12  2019  Non Fiction
# 5        George R. R. Martin          4.4    12643     11  2011      Fiction
# 6        George R. R. Martin          4.7    19735     30  2014      Fiction
# ...

# %% [markdown]
# # Reading data

# %%
import pandas as pd
df = pd.read_csv('bestsellers.csv')
print(df)
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
df.head()
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price  Year        Genre
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction

# %%
df.head(21)
# Out:
#                                                  Name  \
# 0                       10-Day Green Smoothie Cleanse
# 1                                   11/22/63: A Novel
# 2             12 Rules for Life: An Antidote to Chaos
# 3                              1984 (Signet Classics)
# 4   5,000 Awesome Facts (About Everything!) (Natio...
# 5       A Dance with Dragons (A Song of Ice and Fire)
# 6   A Game of Thrones / A Clash of Kings / A Storm...
# 7                      A Gentleman in Moscow: A Novel
# 8       A Higher Loyalty: Truth, Lies, and Leadership
# 9                           A Man Called Ove: A Novel
# 10                          A Man Called Ove: A Novel
# 11  A Patriot's History of the United States: From...
# 12                            A Stolen Life: A Memoir
# 13                   A Wrinkle in Time (Time Quintet)
# 14  Act Like a Lady, Think Like a Man: What Men Re...
# 15  Adult Coloring Book Designs: Stress Relief Col...
# ...

# %%
df.tail()
# Out:
#                                                   Name       Author  \
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)  Jeff Kinney
# 546  You Are a Badass: How to Stop Doubting Your Gr...  Jen Sincero
# 547  You Are a Badass: How to Stop Doubting Your Gr...  Jen Sincero
# 548  You Are a Badass: How to Stop Doubting Your Gr...  Jen Sincero
# 549  You Are a Badass: How to Stop Doubting Your Gr...  Jen Sincero
#
#      User Rating  Reviews  Price  Year        Genre
# 545          4.9     9413      8  2019      Fiction
# 546          4.7    14331      8  2016  Non Fiction
# 547          4.7    14331      8  2017  Non Fiction
# 548          4.7    14331      8  2018  Non Fiction
# 549          4.7    14331      8  2019  Non Fiction

# %%
df.tail(10)
# Out:
#                                                   Name         Author  \
# 540                                             Wonder  R. J. Palacio
# 541                                             Wonder  R. J. Palacio
# 542                                             Wonder  R. J. Palacio
# 543                                             Wonder  R. J. Palacio
# 544                                             Wonder  R. J. Palacio
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)    Jeff Kinney
# 546  You Are a Badass: How to Stop Doubting Your Gr...    Jen Sincero
# 547  You Are a Badass: How to Stop Doubting Your Gr...    Jen Sincero
# 548  You Are a Badass: How to Stop Doubting Your Gr...    Jen Sincero
# 549  You Are a Badass: How to Stop Doubting Your Gr...    Jen Sincero
#
#      User Rating  Reviews  Price  Year        Genre
# 540          4.8    21625      9  2013      Fiction
# 541          4.8    21625      9  2014      Fiction
# ...

# %%
df1 = pd.read_excel('titanic.xlsx')
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df1.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare  ... Unnamed: 16 Unnamed: 17  Unnamed: 18  \
# 0      0         A/5 21171   7.2500  ...         NaN         NaN          NaN
# 1      0          PC 17599  71.2833  ...         NaN         NaN          NaN
# 2      0  STON/O2. 3101282   7.9250  ...         NaN         NaN          NaN
# ...

# %%
df1.head(50)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
# 20           21         0       2
# 21           22         1       2
# 22           23         1       3
# 23           24         1       1
# 24           25         0       3
# 25           26         1       3
# ...

# %%
df1.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare  ... Unnamed: 16  \
# 886    male  27.0      0      0      211536  13.00  ...         NaN
# 887  female  19.0      0      0      112053  30.00  ...         NaN
# 888  female   NaN      1      2  W./C. 6607  23.45  ...         NaN
# 889    male  26.0      0      0      111369  30.00  ...         NaN
# 890    male  32.0      0      0      370376   7.75  ...         NaN
#
#     Unnamed: 17  Unnamed: 18  Unnamed: 19  Unnamed: 20  Unnamed: 21  \
# ...

# %%
df1.tail(50)
# Out:
#      PassengerId  Survived  Pclass  \
# 841          842         0       2
# 842          843         1       1
# 843          844         0       3
# 844          845         0       3
# 845          846         0       3
# 846          847         0       3
# 847          848         0       3
# 848          849         0       2
# 849          850         1       1
# 850          851         0       3
# 851          852         0       3
# 852          853         0       3
# 853          854         1       1
# 854          855         0       2
# 855          856         1       3
# 856          857         1       1
# 857          858         1       1
# 858          859         1       3
# 859          860         0       3
# 860          861         0       3
# 861          862         0       2
# 862          863         1       1
# 863          864         0       3
# 864          865         0       2
# 865          866         1       2
# ...

# %% [markdown]
# # Data Manipulation

# %%
df
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
new_data = df[df['Price'] == 8]
print(new_data)
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 9                            A Man Called Ove: A Novel
# 10                           A Man Called Ove: A Novel
# 18   Adult Coloring Books: A Coloring Book for Adul...
# 39   Broke: The Plan to Restore Our Trust, Truth an...
# 53       Crazy Rich Asians (Crazy Rich Asians Trilogy)
# 61   Dead in the Family (Sookie Stackhouse/True Blo...
# 82   Dog Man: A Tale of Two Kitties: From the Creat...
# 85   Dog Man: Fetch-22: From the Creator of Captain...
# 86   Dog Man: For Whom the Ball Rolls: From the Cre...
# 100                                     Fahrenheit 451
# 101                                     Fahrenheit 451
# 187  Jesus Calling: Enjoying Peace in His Presence ...
# 188  Jesus Calling: Enjoying Peace in His Presence ...
# 189  Jesus Calling: Enjoying Peace in His Presence ...
# 190  Jesus Calling: Enjoying Peace in His Presence ...
# ...

# %%
new_data
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 9                            A Man Called Ove: A Novel
# 10                           A Man Called Ove: A Novel
# 18   Adult Coloring Books: A Coloring Book for Adul...
# 39   Broke: The Plan to Restore Our Trust, Truth an...
# 53       Crazy Rich Asians (Crazy Rich Asians Trilogy)
# 61   Dead in the Family (Sookie Stackhouse/True Blo...
# 82   Dog Man: A Tale of Two Kitties: From the Creat...
# 85   Dog Man: Fetch-22: From the Creator of Captain...
# 86   Dog Man: For Whom the Ball Rolls: From the Cre...
# 100                                     Fahrenheit 451
# 101                                     Fahrenheit 451
# 187  Jesus Calling: Enjoying Peace in His Presence ...
# 188  Jesus Calling: Enjoying Peace in His Presence ...
# 189  Jesus Calling: Enjoying Peace in His Presence ...
# 190  Jesus Calling: Enjoying Peace in His Presence ...
# ...

# %%
x = df[df['Year'] == 2016]
x

# %%
x.head()
# Out:
#                                                  Name  \
# 0                       10-Day Green Smoothie Cleanse
# 9                           A Man Called Ove: A Novel
# 15  Adult Coloring Book Designs: Stress Relief Col...
# 19                                 Alexander Hamilton
# 36                           Between the World and Me
#
#                          Author  User Rating  Reviews  Price  Year  \
# 0                      JJ Smith          4.7    17350      8  2016
# 9               Fredrik Backman          4.6    23848      8  2016
# 15  Adult Coloring Book Designs          4.5     2313      4  2016
# 19                  Ron Chernow          4.8     9198     13  2016
# 36             Ta-Nehisi Coates          4.7    10070     13  2016
#
#           Genre
# 0   Non Fiction
# 9       Fiction
# 15  Non Fiction
# 19  Non Fiction
# 36  Non Fiction

# %%
x.head(20)
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 9                            A Man Called Ove: A Novel
# 15   Adult Coloring Book Designs: Stress Relief Col...
# 19                                  Alexander Hamilton
# 36                            Between the World and Me
# 37                                         Born to Run
# 43   Calm the F*ck Down: An Irreverent Adult Colori...
# 49   Cravings: Recipes for All the Food You Want to...
# 64                      Dear Zoo: A Lift-the-Flap Book
# 88              Double Down (Diary of a Wimpy Kid #11)
# 100                                     Fahrenheit 451
# 102  Fantastic Beasts and Where to Find Them: The O...
# 112                                    First 100 Words
# 124                               Giraffes Can't Dance
# 151                           Hamilton: The Revolution
# 153  Harry Potter and the Chamber of Secrets: The I...
# ...

# %%
df
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
var_name = df[df['Price'] > 10]
var_name
# Out:
#                                                   Name  \
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# 5        A Dance with Dragons (A Song of Ice and Fire)
# 6    A Game of Thrones / A Clash of Kings / A Storm...
# ..                                                 ...
# 535                          Where the Wild Things Are
# 536  Whose Boat Is This Boat?: Comments That Don't ...
# 537  Wild: From Lost to Found on the Pacific Crest ...
# 538  Winter of the World: Book Two of the Century T...
# 539  Women Food and God: An Unexpected Path to Almo...
#
#                                Author  User Rating  Reviews  Price  Year  \
# 1                        Stephen King          4.6     2052     22  2011
# 2                  Jordan B. Peterson          4.7    18979     15  2018
# 4            National Geographic Kids          4.8     7665     12  2019
# ...

# %%
fiction_book = df[df['Genre'] == 'Fiction']
fiction_book
# Out:
#                                                   Name               Author  \
# 1                                    11/22/63: A Novel         Stephen King
# 3                               1984 (Signet Classics)        George Orwell
# 5        A Dance with Dragons (A Song of Ice and Fire)  George R. R. Martin
# 6    A Game of Thrones / A Clash of Kings / A Storm...  George R. R. Martin
# 7                       A Gentleman in Moscow: A Novel          Amor Towles
# ..                                                 ...                  ...
# 541                                             Wonder        R. J. Palacio
# 542                                             Wonder        R. J. Palacio
# 543                                             Wonder        R. J. Palacio
# 544                                             Wonder        R. J. Palacio
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)          Jeff Kinney
#
#      User Rating  Reviews  Price  Year    Genre
# ...

# %%
non_fiction_book = df[df['Genre'] == 'Non Fiction']
non_fiction_book
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 2              12 Rules for Life: An Antidote to Chaos
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# 8        A Higher Loyalty: Truth, Lies, and Leadership
# 11   A Patriot's History of the United States: From...
# ..                                                 ...
# 539  Women Food and God: An Unexpected Path to Almo...
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 2          Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# ...

# %%
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
len(df1)
# Out:
# 891

# %%
fiction_book
# Out:
#                                                   Name               Author  \
# 1                                    11/22/63: A Novel         Stephen King
# 3                               1984 (Signet Classics)        George Orwell
# 5        A Dance with Dragons (A Song of Ice and Fire)  George R. R. Martin
# 6    A Game of Thrones / A Clash of Kings / A Storm...  George R. R. Martin
# 7                       A Gentleman in Moscow: A Novel          Amor Towles
# ..                                                 ...                  ...
# 541                                             Wonder        R. J. Palacio
# 542                                             Wonder        R. J. Palacio
# 543                                             Wonder        R. J. Palacio
# 544                                             Wonder        R. J. Palacio
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)          Jeff Kinney
#
#      User Rating  Reviews  Price  Year    Genre
# ...

# %%
len(fiction_book)
# Out:
# 240

# %%
fiction_book.columns
# Out:
# Index(['Name', 'Author', 'User Rating', 'Reviews', 'Price', 'Year', 'Genre'], dtype='object')

# %%
fiction_book['Price'].head(100)

# %%
book_list = fiction_book['Name']
book_list.head(20)

# %% [markdown]
# # Day 4

# %%
import pandas as pd
data = {
    'name':['Addis','Elias','Hargewoyin','Bele'],
    'Age': [32,38,32,27],
    'department':['finance','HR', 'HR', "finance"]
}

df = pd.DataFrame(data)
print(df)
